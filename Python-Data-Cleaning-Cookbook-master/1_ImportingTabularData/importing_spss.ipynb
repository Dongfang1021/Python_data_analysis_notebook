# %%
import pandas as pd
import numpy as np
import pyreadstat
pd.set_option('display.max_columns', 5)
pd.set_option('display.width', 75)
pd.options.display.float_format = '{:, .2f}'.format

# %%
nls97spss, metaspss = pyreadstat.read_sav('data/nls97.sav')
nls97spss.dtypes
# Out:
# R0000100    float64
# R0536300    float64
# R0536401    float64
# R0536402    float64
# R1235800    float64
# R1482600    float64
# R9793800    float64
# R9793900    float64
# R9871900    float64
# R9872000    float64
# R9872200    float64
# R9872400    float64
# S8646900    float64
# S8647000    float64
# S8647100    float64
# S8647200    float64
# S8647300    float64
# S8647400    float64
# S8647500    float64
# S8647600    float64
# S8647700    float64
# S8647800    float64
# T6651700    float64
# U1836800    float64
# U1836900    float64
# U1837000    float64
# U1837100    float64
# U1837200    float64
# U1837300    float64
# U1845400    float64
# U1852400    float64
# U1852600    float64
# U1852700    float64
# U2166200    float64
# U2166300    float64
# U2166400    float64
# U2166500    float64
# U2857300    float64
# U2962800    float64
# U2962900    float64
# U2963000    float64
# Z9063900    float64
# dtype: object

# %%
nls97spss.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     401                         if cls is not object \
#     402                                 and callable(cls.__dict__.get('__repr__')):
# --> 403                             return _repr_pprint(obj, self, cycle)
#     404
#     405             return _default_pprint(obj, self, cycle)
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     701     """A pprint that just redirects to the normal repr function."""
#     702     # Find newlines and replace them with p.break_()
# --> 703     output = repr(obj)
#     704     for idx,output_line in enumerate(output.splitlines()):
#     705         if idx:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/frame.py in __repr__(self)
#     685             line_width=width,
#     686             max_colwidth=max_colwidth,
# --> 687             show_dimensions=show_dimensions,
#     688         )
#     689
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     818                 line_width=line_width,
#     819             )
# --> 820             return formatter.to_string(buf=buf, encoding=encoding)
#     821
#     822     # ----------------------------------------------------------------------
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in to_string(self, buf, encoding)
#     914         encoding: Optional[str] = None,
#     915     ) -> Optional[str]:
# --> 916         return self.get_result(buf=buf, encoding=encoding)
#     917
#     918     def to_latex(
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in write_result(self, buf)
#     823         else:
#     824
# --> 825             strcols = self._to_str_columns()
#     826             if self.line_width is None:  # no need to wrap around just print
#     827                 # the whole frame
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     759                     self.col_space or 0, *(self.adj.len(x) for x in cheader)
#     760                 )
# --> 761                 fmt_values = self._format_col(i)
#     762                 fmt_values = _make_fixed_width(
#     763                     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     954             na_rep=self.na_rep,
#     955             space=self.col_space,
# --> 956             decimal=self.decimal,
#     957         )
#     958
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# ValueError: Invalid format specifier
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     983         Klass = NotebookFormatter if notebook else HTMLFormatter
#     984         return Klass(self, classes=classes, border=border).get_result(
# --> 985             buf=buf, encoding=encoding
#     986         )
#     987
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     237             self._write_header(indent + self.indent_delta)
#     238
# --> 239         self._write_body(indent + self.indent_delta)
#     240
#     241         self.write("</table>", indent)
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     383     def _write_body(self, indent: int) -> None:
#     384         self.write("<tbody>", indent)
# --> 385         fmt_values = self._get_formatted_values()
#     386
#     387         # write values
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in _get_formatted_values(self)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in <dictcomp>(.0)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     954             na_rep=self.na_rep,
#     955             space=self.col_space,
# --> 956             decimal=self.decimal,
#     957         )
#     958
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# ValueError: Invalid format specifier

# %%
nls97spss['R0536300'].value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     401                         if cls is not object \
#     402                                 and callable(cls.__dict__.get('__repr__')):
# --> 403                             return _repr_pprint(obj, self, cycle)
#     404
#     405             return _default_pprint(obj, self, cycle)
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     701     """A pprint that just redirects to the normal repr function."""
#     702     # Find newlines and replace them with p.break_()
# --> 703     output = repr(obj)
#     704     for idx,output_line in enumerate(output.splitlines()):
#     705         if idx:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in to_string(self)
#     358             )
#     359
# --> 360         fmt_index, have_header = self._get_formatted_index()
#     361         fmt_values = self._get_formatted_values()
#     362
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _get_formatted_index(self)
#     338         else:
#     339             have_header = index.name is not None
# --> 340             fmt_index = index.format(name=True)
#     341         return fmt_index, have_header
#     342
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/indexes/base.py in format(self, name, formatter, **kwargs)
#     964             return header + list(self.map(formatter))
#     965
# --> 966         return self._format_with_header(header, **kwargs)
#     967
#     968     def _format_with_header(self, header, na_rep="NaN", **kwargs):
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/indexes/base.py in _format_with_header(self, header, na_rep, **kwargs)
#     988
#     989         else:
# --> 990             result = _trim_front(format_array(values, None, justify="left"))
#     991         return header + result
#     992
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# ValueError: Invalid format specifier

# %%
metaspss.variable_value_labels['R0536300']
# Out:
# {0.0: 'No Information', 1.0: 'Male', 2.0: 'Female'}

# %%
nls97spss['R0536300'].map(metaspss.variable_value_labels['R0536300']).value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     401                         if cls is not object \
#     402                                 and callable(cls.__dict__.get('__repr__')):
# --> 403                             return _repr_pprint(obj, self, cycle)
#     404
#     405             return _default_pprint(obj, self, cycle)
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     701     """A pprint that just redirects to the normal repr function."""
#     702     # Find newlines and replace them with p.break_()
# --> 703     output = repr(obj)
#     704     for idx,output_line in enumerate(output.splitlines()):
#     705         if idx:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in to_string(self)
#     359
#     360         fmt_index, have_header = self._get_formatted_index()
# --> 361         fmt_values = self._get_formatted_values()
#     362
#     363         if self.truncate_v:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _get_formatted_values(self)
#     346             None,
#     347             float_format=self.float_format,
# --> 348             na_rep=self.na_rep,
#     349         )
#     350
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# ValueError: Invalid format specifier

# %%
nls97spss = pyreadstat.set_value_labels(nls97spss, metaspss, formats_as_category=True)

# %%
nls97spss.columns = metaspss.column_labels
nls97spss['KEY!SEX (SYMBOL) 1997'].value_counts(normalize=True)
nls97spss.dtypes
nls97spss.columns = nls97spss.columns.\
    str.lower().\
    str.replace(' ','_').\
    str.replace('[^a-z0-9_]', '')
nls97spss.set_index('pubid__yth_id_code_1997', inplace=True)

# %%
nls97spss.columns = metaspss.column_labels
nls97spss.columns = nls97spss.columns.\
  str.lower().\
  str.replace(' ','_').\
  str.replace('[^a-z0-9_]', '')
nls97spss.dtypes
nls97spss.head()
nls97spss.govt_responsibility__provide_jobs_2006.\
  value_counts(sort=False)
nls97spss.set_index('pubid__yth_id_code_1997', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d0e681219132> in <module>()
# ----> 1 nls97spss.columns = metaspss.column_labels
#       2 nls97spss.columns = nls97spss.columns.  str.lower().  str.replace(' ','_').  str.replace('[^a-z0-9_]', '')
#       3 nls97spss.dtypes
#       4 nls97spss.head()
#       5 nls97spss.govt_responsibility__provide_jobs_2006.  value_counts(sort=False)
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 41 elements, new values have 42 elements

# %%
nls97stata.columns = metastata.column_labels
nls97stata.columns = nls97stata.columns.\
    str.lower().\
    str.replace(' ','_').\
    str.replace('[^a-z0-9_]', '')
nls97stata.dtypes
nls97stata.head()
nls97stata.govt_responsibility__provide_jobs_2006.\
  value_counts(sort=False)
nls97stata.min()
nls97stata.replace(list(range(-9,0)), np.nan, inplace=True)
nls97stata.min()
nls97stata.set_index('pubid__yth_id_code_1997', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7e2d9c26ac05> in <module>()
# ----> 1 nls97stata.columns = metastata.column_labels
#       2 nls97stata.columns = nls97stata.columns.    str.lower().    str.replace(' ','_').    str.replace('[^a-z0-9_]', '')
#       3 nls97stata.dtypes
#       4 nls97stata.head()
#       5 nls97stata.govt_responsibility__provide_jobs_2006.  value_counts(sort=False)
#
# NameError: name 'metastata' is not defined

# %%
nls97sas, metasas = pyreadstat.read_sas7bdat('data/nls97.sas7bdat', catalog_file='data/nlsformats3.sas7bcat', formats_as_category=True)
nls97sas.columns = metasas.column_labels
nls97sas.columns = nls97sas.columns.\
    str.lower().\
    str.replace(' ','_').\
    str.replace('[^a-z0-9_]', '')
nls97sas.head()
nls97sas.keysex_symbol_1997.value_counts()
nls97sas.set_index('pubid__yth_id_code_1997', inplace=True)

# %%
nls97sas.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     401                         if cls is not object \
#     402                                 and callable(cls.__dict__.get('__repr__')):
# --> 403                             return _repr_pprint(obj, self, cycle)
#     404
#     405             return _default_pprint(obj, self, cycle)
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     701     """A pprint that just redirects to the normal repr function."""
#     702     # Find newlines and replace them with p.break_()
# --> 703     output = repr(obj)
#     704     for idx,output_line in enumerate(output.splitlines()):
#     705         if idx:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/frame.py in __repr__(self)
#     685             line_width=width,
#     686             max_colwidth=max_colwidth,
# --> 687             show_dimensions=show_dimensions,
#     688         )
#     689
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     818                 line_width=line_width,
#     819             )
# --> 820             return formatter.to_string(buf=buf, encoding=encoding)
#     821
#     822     # ----------------------------------------------------------------------
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in to_string(self, buf, encoding)
#     914         encoding: Optional[str] = None,
#     915     ) -> Optional[str]:
# --> 916         return self.get_result(buf=buf, encoding=encoding)
#     917
#     918     def to_latex(
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in write_result(self, buf)
#     823         else:
#     824
# --> 825             strcols = self._to_str_columns()
#     826             if self.line_width is None:  # no need to wrap around just print
#     827                 # the whole frame
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _to_str_columns(self)
#     719         # may include levels names also
#     720
# --> 721         str_index = self._get_formatted_index(frame)
#     722
#     723         if not is_list_like(self.header) and not self.header:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _get_formatted_index(self, frame)
#    1059             )
#    1060         else:
# -> 1061             fmt_index = [index.format(name=self.show_row_idx_names, formatter=fmt)]
#    1062
#    1063         fmt_index = [
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/indexes/base.py in format(self, name, formatter, **kwargs)
#     964             return header + list(self.map(formatter))
#     965
# --> 966         return self._format_with_header(header, **kwargs)
#     967
#     968     def _format_with_header(self, header, na_rep="NaN", **kwargs):
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/indexes/base.py in _format_with_header(self, header, na_rep, **kwargs)
#     988
#     989         else:
# --> 990             result = _trim_front(format_array(values, None, justify="left"))
#     991         return header + result
#     992
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# ValueError: Invalid format specifier
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     983         Klass = NotebookFormatter if notebook else HTMLFormatter
#     984         return Klass(self, classes=classes, border=border).get_result(
# --> 985             buf=buf, encoding=encoding
#     986         )
#     987
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in _write_table(self, indent)
#     237             self._write_header(indent + self.indent_delta)
#     238
# --> 239         self._write_body(indent + self.indent_delta)
#     240
#     241         self.write("</table>", indent)
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in _write_body(self, indent)
#     383     def _write_body(self, indent: int) -> None:
#     384         self.write("<tbody>", indent)
# --> 385         fmt_values = self._get_formatted_values()
#     386
#     387         # write values
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in _get_formatted_values(self)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/html.py in <dictcomp>(.0)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_col(self, i)
#     954             na_rep=self.na_rep,
#     955             space=self.col_space,
# --> 956             decimal=self.decimal,
#     957         )
#     958
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in _format_strings(self)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# /Users/dongfanghu/miniconda3/envs/bioinfo/lib/python3.6/site-packages/pandas/io/formats/format.py in <listcomp>(.0)
#    1434         # shortcut
#    1435         if self.formatter is not None:
# -> 1436             return [self.formatter(x) for x in self.values]
#    1437
#    1438         return list(self.get_result_as_array())
#
# ValueError: Invalid format specifier
